# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
from matplotlib.ticker import PercentFormatter

# %%
google_analytics = pd.read_excel("/content/drive/MyDrive/Acelera/Arquivos - Marketing e Vendas/Base_Google_Analytics.xlsx")

# %%
google_analytics.head()
# Out:
#   Data de Acesso  Acessos ao Site
# 0     2022-09-01             2432
# 1     2022-09-02             2128
# 2     2022-09-03             2280
# 3     2022-09-04             1596
# 4     2022-09-05             2432

# %%
google_analytics['Mês de acesso'] = google_analytics['Data de Acesso'].dt.to_period("M")

# %%
google_analytics.describe()
# Out:
#        Acessos ao Site
# count       181.000000
# mean       7855.712707
# std        3198.717994
# min        1596.000000
# 25%        5472.000000
# 50%        8284.000000
# 75%       10336.000000
# max       15276.000000

# %%
sns.lineplot(data=google_analytics, x=google_analytics["Mês de acesso"].astype(str), y="Acessos ao Site", color='green', sort=False, ci= False);
plt.title("Acessos ao site");
plt.show();
# Out:
# <ipython-input-6-710490fa6fa3>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=google_analytics, x=google_analytics["Mês de acesso"].astype(str), y="Acessos ao Site", color='green', sort=False, ci= False);

# %%
google_analytics.to_excel("/content/drive/MyDrive/Acelera/Bases tratadas/base_google_analytics_tratada.xlsx", index = False)
